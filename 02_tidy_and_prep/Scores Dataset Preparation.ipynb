# %%
import pandas as pd
import numpy as np

# %%
import pycountry

# %%
# Scores dataset output folder
DATASET_OUTPUT_DIR = "../dataset/"

# Dataset for visualization output folder
VIZ_DATA_DIR = "../03_visualization/"

# %% [markdown]
# ### TIMES HIGHER EDUCATION SCORES

# %%
the_df = pd.read_csv('../data_raw/THE_World_Rankings.csv', index_col=0)
the_score_lab = 'scores_overall'

# %%
the_df.head(3)
# Out:
#         location                                   name     nid rank  \
# 0  United States                     Harvard University     466    1
# 1  United States     California Institute of Technology  128779    2
# 2  United States  Massachusetts Institute of Technology     471    3
#
#    scores_citations  scores_citations_rank scores_industry_income  \
# 0              98.8                      8                   34.5
# 1              99.9                      1                   83.7
# 2              99.9                      2                   87.5
#
#    scores_industry_income_rank scores_international_outlook  \
# 0                          105                         72.4
# 1                           24                         54.6
# 2                           21                         82.3
#
#    scores_international_outlook_rank  ... scores_overall_rank  \
# 0                                 49  ...                   1
# 1                                 93  ...                   2
# 2                                 36  ...                   3
#
#    scores_research  scores_research_rank  scores_teaching  \
# 0             98.7                     2             99.7
# 1             98.0                     4             97.7
# 2             91.4                    11             97.8
#
#    scores_teaching_rank  year  stats_female_male_ratio stats_number_students  \
# 0                     1  2011                      NaN                   NaN
# 1                     4  2011                      NaN                   NaN
# 2                     3  2011                      NaN                   NaN
#
#   stats_pc_intl_students stats_student_staff_ratio
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
#
# [3 rows x 21 columns]

# %%
the_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10980 entries, 0 to 10979
# Data columns (total 21 columns):
# location                             10980 non-null object
# name                                 10980 non-null object
# nid                                  10980 non-null int64
# rank                                 10980 non-null object
# scores_citations                     10530 non-null float64
# scores_citations_rank                10980 non-null int64
# scores_industry_income               10530 non-null object
# scores_industry_income_rank          10980 non-null int64
# scores_international_outlook         10530 non-null object
# scores_international_outlook_rank    10980 non-null int64
# scores_overall                       10530 non-null object
# scores_overall_rank                  10980 non-null int64
# scores_research                      10530 non-null float64
# scores_research_rank                 10980 non-null int64
# scores_teaching                      10530 non-null float64
# scores_teaching_rank                 10980 non-null int64
# year                                 10980 non-null int64
# stats_female_male_ratio              8740 non-null object
# stats_number_students                9177 non-null object
# stats_pc_intl_students               9177 non-null object
# stats_student_staff_ratio            9177 non-null float64
# dtypes: float64(4), int64(8), object(9)
# memory usage: 1.8+ MB

# %%
# Convert Overall score to numeric
the_df.loc[:, 'scores_overall_num'] = pd.to_numeric(the_df.scores_overall, errors='coerce').round(2)

# %%
the_df.groupby('year').agg({
    'scores_overall_num': lambda x: x.isna().sum(),
    'nid': ['count', 'nunique']
})
# Out:
#      scores_overall_num   nid
#                <lambda> count nunique
# year
# 2011                0.0   200     200
# 2012              202.0   402     402
# 2013              200.0   400     400
# 2014              200.0   400     400
# 2015              200.0   401     401
# 2016                0.0   800     800
# 2017              780.0   981     981
# 2018              903.0  1103    1103
# 2019             1058.0  1258    1258
# 2020             1195.0  1397    1397
# 2021             1324.0  1526    1526
# 2022             1911.0  2112    2112

# %% [markdown]
# #### FIX AND RE-CALCULATE OVERALL SCORES

# %%
# Weights of scores in total score
the_weights = {
    'labs': ['scores_research', 'scores_teaching', 'scores_citations', 'scores_international_outlook', 'scores_industry_income'],
    2011: [30, 30, 32.5, 5, 2.5],
    2012: [30, 30, 30, 7.5, 2.5]
}

# %%
# Replace '-' with NANs and convert to floats
the_df.loc[ :,
    ['scores_international_outlook', 'scores_industry_income']
] = the_df.loc[:, ['scores_international_outlook', 'scores_industry_income']].replace('-', np.nan)

the_df.loc[:, the_weights['labs']] = the_df.loc[:, the_weights['labs']].astype('float32').round(2)

# %%
# Fix 2016 scores_overall having zero (0) values by replacing to NANs
the_df.loc[
    (the_df.year==2016)&(the_df.scores_overall_num==0),
    'scores_overall_num'
] = np.nan

the_df.loc[:, 'scores_overall_calc'] = np.nan

for year in np.unique(the_df.year):
    
    sub_df = the_df.loc[
        the_df.year==year,
        the_weights['labs']
    ]
    
    res = np.ma.average(
        np.ma.array(sub_df, mask=sub_df.isnull()),
        axis=1,
        weights=the_weights.get(year, the_weights[2012])
    )
    
    the_df.loc[
        the_df.year==year,
        'scores_overall_calc'
    ] = np.round(res.data, 2)

# %%
# Check calculations disrepancy
the_df.groupby('year').apply(
    lambda tx: (tx.scores_overall_num - tx.scores_overall_calc).abs().median()
)
# Out:
# year
# 2011    0.03
# 2012    0.03
# 2013    0.03
# 2014    0.03
# 2015    0.03
# 2016    0.03
# 2017    0.02
# 2018    0.02
# 2019    0.03
# 2020    0.02
# 2021    0.03
# 2022    0.03
# dtype: float64

# %%
# Replace scores_overall NAN values with calculated scores
the_df.loc[
    the_df.scores_overall_num.isnull(),
    'scores_overall_num'
] = the_df.loc[ the_df.scores_overall_num.isnull(), 'scores_overall_calc' ]

# %%
# Save scores dataset to csv
#the_df.loc[
#    :,
#    ['location', 'name', 'nid', 'year', 'scores_overall_num'] + the_weights['labs']
#].to_csv(DATASET_OUTPUT_DIR + 'the_scores.csv', float_format = '%.2f')

# %% [markdown]
# ### SHANGHAI RANKINGS SCORES

# %%
arwu_df = pd.read_csv('../data_raw/ARWU_World_Rankings.csv', index_col=0)
arwu_score_lab = 'score'

# %%
arwu_df.head(3)
# Out:
#    Alumni  Award   HiCi    N&S    PCP    PUB ranking         region  \
# 0     NaN  100.0  100.0  100.0   68.7  100.0       1  United States
# 1     NaN   76.2   88.2   73.8   80.5   72.2       2  United States
# 2     NaN   72.9   68.0   64.1  100.0   52.0       3  United States
#
#   regionLogo regionRanking  score                          univNameEn  \
# 0         us             1  100.0                  Harvard University
# 1         us             2   83.5                 Stanford University
# 2         us             3   76.3  California Institute of Technology
#
#                                univUp  year
# 0                  harvard-university  2003
# 1                 stanford-university  2003
# 2  california-institute-of-technology  2003

# %%
arwu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11816 entries, 0 to 999
# Data columns (total 14 columns):
# Alumni           11315 non-null float64
# Award            11815 non-null float64
# HiCi             11815 non-null float64
# N&S              11742 non-null float64
# PCP              11815 non-null float64
# PUB              11815 non-null float64
# ranking          11816 non-null object
# region           11816 non-null object
# regionLogo       11816 non-null object
# regionRanking    11816 non-null object
# score            1904 non-null float64
# univNameEn       11816 non-null object
# univUp           10802 non-null object
# year             11816 non-null int64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 1.4+ MB

# %%
# Check overall scores NA values and duplicate universities
arwu_df.groupby('year').agg({
    'score': lambda x: x.isna().sum(),
    'univNameEn': ['count', 'nunique', 'size'],
})
# Out:
#         score univNameEn
#      <lambda>      count nunique  size
# year
# 2003    399.0        500     499   500
# 2004    402.0        502     502   502
# 2005    400.0        500     500   500
# 2006    399.0        500     500   500
# 2007    409.0        510     510   510
# 2008    403.0        503     503   503
# 2009    401.0        501     501   501
# 2010    400.0        500     500   500
# 2011    399.0        500     500   500
# 2012    400.0        500     500   500
# 2013    400.0        500     500   500
# 2014    400.0        500     500   500
# 2015    400.0        500     500   500
# 2016    400.0        500     500   500
# 2017    700.0        800     800   800
# 2018    900.0       1000    1000  1000
# 2019    900.0       1000    1000  1000
# 2020    900.0       1000    1000  1000
# 2021    900.0       1000    1000  1000

# %% [markdown]
# #### What is duplicate university name from 2003?

# %%
arwu_df.loc[
    arwu_df.year==2003,
    'univNameEn'
].value_counts().head(3)
# Out:
# University of Duisburg-Essen    2
# Emory University                1
# The University of Adelaide      1
# Name: univNameEn, dtype: int64

# %%
arwu_df.loc[
    (arwu_df.year==2003)&(arwu_df.univNameEn == 'University of Duisburg-Essen')
]
# Out:
#      Alumni  Award  HiCi  N&S  PCP   PUB  ranking   region regionLogo  \
# 483     NaN    0.0   0.0  3.5  8.0  28.4  451-500  Germany         de
# 484     NaN    0.0   0.0  2.0  7.9  29.6  451-500  Germany         de
#
#     regionRanking  score                    univNameEn  \
# 483         39-43    NaN  University of Duisburg-Essen
# 484         39-43    NaN  University of Duisburg-Essen
#
#                              univUp  year
# 483  university-of-duisburg-essen-1  2003
# 484  university-of-duisburg-essen-2  2003

# %% [markdown]
# #### 'Alumni' scores from 2003 are NAs

# %%
arwu_df.loc[
    arwu_df.Alumni.isnull()
].head(3)
# Out:
#    Alumni  Award   HiCi    N&S    PCP    PUB ranking         region  \
# 0     NaN  100.0  100.0  100.0   68.7  100.0       1  United States
# 1     NaN   76.2   88.2   73.8   80.5   72.2       2  United States
# 2     NaN   72.9   68.0   64.1  100.0   52.0       3  United States
#
#   regionLogo regionRanking  score                          univNameEn  \
# 0         us             1  100.0                  Harvard University
# 1         us             2   83.5                 Stanford University
# 2         us             3   76.3  California Institute of Technology
#
#                                univUp  year
# 0                  harvard-university  2003
# 1                 stanford-university  2003
# 2  california-institute-of-technology  2003

# %%
arwu_df.loc[
    arwu_df.Alumni.isnull()
].tail(3)
# Out:
#      Alumni  Award  HiCi  N&S  PCP   PUB  ranking         region regionLogo  \
# 498     NaN    0.0   0.0  3.2  8.0  28.9  451-500          Spain         es
# 499     NaN    0.0   0.0  6.7  6.5  26.9  451-500  United States         us
# 587     NaN    NaN   NaN  NaN  NaN   NaN  501-600        Finland         fi
#
#     regionRanking  score                univNameEn                    univUp  \
# 498          8-13    NaN    University of Zaragoza    university-of-zaragoza
# 499       155-161    NaN  West Virginia University  west-virginia-university
# 587           4-6    NaN        Tampere University        tampere-university
#
#      year
# 498  2003
# 499  2003
# 587  2020

# %% [markdown]
# #### WEIGHTS

# %%
arwu_weights = {
    'labs': ['Alumni', 'Award', 'HiCi', 'PUB', 'PCP'],
    'wNS': [10, 20, 20, 20, 10, 20],
    'woNS': [10*1.25, 20*1.25, 20*1.25, 20*1.25, 10*1.25]
}

# %% [markdown]
# #### Drop NAs

# %%
# Drop 2003 year, it was first and the only year without 'Alumni' scores, methodoly for this year is not clear
arwu_df = arwu_df.loc[
    arwu_df.year!=2003
]

# Drop the only row with no any scores provided
arwu_df = arwu_df.loc[
    ~arwu_df[arwu_weights['labs']].isna().all(axis=1)
]

# %%
arwu_df.isna().sum()
# Out:
# Alumni              0
# Award               0
# HiCi                0
# N&S                73
# PCP                 0
# PUB                 0
# ranking             0
# region              0
# regionLogo          0
# regionRanking       0
# score            9512
# univNameEn          0
# univUp            946
# year                0
# dtype: int64

# %% [markdown]
# #### RE-CALCULATE OVERALL SCORES

# %%
arwu_df.loc[:, 'scores_overall_num'] = np.nan

# Universities with N&S score provided
sub_df = arwu_df.loc[
    ~arwu_df['N&S'].isnull(),
    arwu_weights['labs'] + ['N&S']
]

arwu_df.loc[
    ~arwu_df['N&S'].isnull(),
    'scores_overall_num'
] = np.average(sub_df, axis=1, weights=arwu_weights['wNS'])

# Universities without N&S score provided
sub_df = arwu_df.loc[
    arwu_df['N&S'].isnull(),
    arwu_weights['labs']
]

arwu_df.loc[
    arwu_df['N&S'].isnull(),
    'scores_overall_num'
] = np.average(sub_df, axis=1, weights=arwu_weights['woNS'])

# %%
# The highest scoring institution is assigned a score of 100,
# and other institutions are calculated as a percentage of the top score. (ARWU methodology)

arwu_df.loc[:, 'scores_overall_calc'] = arwu_df.groupby('year').apply(
    lambda tx: (tx.scores_overall_num / tx.scores_overall_num.max() * 100).round(1)
).values

# %%
# Check calculations disrepancy
arwu_df.groupby('year').apply(
    lambda tx: (tx.score - tx.scores_overall_calc).abs().mean(skipna=True)
)
# Out:
# year
# 2004    0.007000
# 2005    0.012000
# 2006    0.006931
# 2007    0.007921
# 2008    0.009000
# 2009    0.013000
# 2010    0.006000
# 2011    0.008911
# 2012    0.012000
# 2013    0.012000
# 2014    0.009000
# 2015    0.009000
# 2016    0.011000
# 2017    0.008000
# 2018    0.008000
# 2019    0.011000
# 2020    0.009000
# 2021    0.009000
# dtype: float64

# %%
arwu_df.head()
# Out:
#    Alumni  Award   HiCi    N&S   PCP    PUB ranking          region  \
# 0    98.6  100.0  100.0  100.0  60.6  100.0       1   United States
# 1    41.2   72.2   96.1   75.2  68.1   72.3       2   United States
# 2   100.0   93.4   56.6   58.5  73.2   70.2       3  United Kingdom
# 3    70.0   76.0   74.1   75.6  45.1   72.7       4   United States
# 4    74.1   78.9   73.6   69.1  47.5   64.6       5   United States
#
#   regionLogo regionRanking  score  \
# 0         us             1  100.0
# 1         us             2   77.2
# 2         gb             1   76.2
# 3         us             3   74.2
# 4         us             4   72.4
#
#                                     univNameEn  \
# 0                           Harvard University
# 1                          Stanford University
# 2                      University of Cambridge
# 3           University of California, Berkeley
# 4  Massachusetts Institute of Technology (MIT)
#
#                                       univUp  year  scores_overall_num  \
# 0                         harvard-university  2004               95.92
# 1                        stanford-university  2004               74.09
# 2                    university-of-cambridge  2004               73.06
# 3          university-of-california-berkeley  2004               71.19
# 4  massachusetts-institute-of-technology-mit  2004               69.40
#
#    scores_overall_calc
# 0                100.0
# 1                 77.2
# 2                 76.2
# 3                 74.2
# 4                 72.4

# %%
# Save .csv
#arwu_df.loc[
#    :,
#    ['region', 'univNameEn', 'univUp', 'year', 'scores_overall_calc'] + arwu_weights['labs'] + ['N&S']
#].to_csv(DATASET_OUTPUT_DIR + 'arwu_scores.csv')

# %% [markdown]
# ### QS RANKINGS SCORES

# %%
qs_df = pd.read_csv('../data_raw/QS_World_Rankings.csv', index_col=0)
qs_score_lab = 'Overall Score'

# %%
qs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10047 entries, 0 to 10046
# Data columns (total 18 columns):
# City                              9814 non-null object
# Natural Sciences                  865 non-null float64
# Life Sciences And Medicine        3030 non-null float64
# Engineering And Technology        3030 non-null float64
# Arts And Humanities               3041 non-null float64
# International Students            7466 non-null float64
# Social Sciences And Management    3039 non-null float64
# Citations Per Faculty             7443 non-null float64
# Faculty Student                   7524 non-null float64
# International Faculty             7386 non-null float64
# Academic Reputation               6939 non-null float64
# Employer Reputation               7066 non-null float64
# Location                          10047 non-null object
# NID                               10047 non-null int64
# Overall Score                     4694 non-null float64
# Region                            10047 non-null object
# University                        10047 non-null object
# Year                              10047 non-null int64
# dtypes: float64(12), int64(2), object(4)
# memory usage: 1.5+ MB

# %%
qs_df.groupby('Year').agg({
    'Overall Score': lambda x: x.isna().sum(),
    'NID': ['count', 'nunique', 'size']
})
# Out:
#      Overall Score   NID
#           <lambda> count nunique  size
# Year
# 2012         369.0   866     865   866
# 2014         403.0   900     900   900
# 2015         388.0   885     885   885
# 2016         515.0   914     914   914
# 2017         533.0   933     933   933
# 2018         577.0   977     977   977
# 2019         515.0  1018    1018  1018
# 2020         570.0  1069    1069  1069
# 2021         684.0  1185    1185  1185
# 2022         799.0  1300    1300  1300

# %%
qs_df.head(5)
# Out:
#         City  Natural Sciences  Life Sciences And Medicine  \
# 0  CAMBRIDGE             95.06                       60.89
# 1  CAMBRIDGE             98.50                       82.75
# 2  CAMBRIDGE            100.00                      100.00
# 3     LONDON             40.24                       49.02
# 4     OXFORD             89.84                       78.11
#
#    Engineering And Technology  Arts And Humanities  International Students  \
# 0                      100.00                46.27                    96.5
# 1                       66.51                95.21                    96.0
# 2                       46.14               100.00                    78.4
# 3                       33.13                54.56                    99.9
# 4                       52.70                97.66                    95.8
#
#    Social Sciences And Management  Citations Per Faculty  Faculty Student  \
# 0                           64.62                   99.3             99.9
# 1                           72.97                   97.0             98.3
# 2                          100.00                  100.0             98.6
# 3                           42.15                   94.0             98.4
# 4                           76.47                   89.4            100.0
#
#    International Faculty  Academic Reputation  Employer Reputation  \
# 0                   86.4                100.0                100.0
# 1                   98.2                100.0                100.0
# 2                   90.0                100.0                100.0
# 3                   96.3                 99.6                 95.6
# 4                   98.0                100.0                100.0
#
#          Location     NID  Overall Score         Region  \
# 0   UNITED STATES  294850         100.00  NORTH AMERICA
# 1  UNITED KINGDOM  294561          99.78         EUROPE
# 2   UNITED STATES  294270          99.15  NORTH AMERICA
# 3  UNITED KINGDOM  294014          98.69         EUROPE
# 4  UNITED KINGDOM  294654          98.57         EUROPE
#
#                                     University  Year
# 0  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)  2012
# 1                      UNIVERSITY OF CAMBRIDGE  2012
# 2                           HARVARD UNIVERSITY  2012
# 3                                          UCL  2012
# 4                         UNIVERSITY OF OXFORD  2012

# %% [markdown]
# #### What is the duplicate university ('NID') from 2012?

# %%
qs_df.loc[
    qs_df.Year==2012,
    'NID'
].value_counts().head(3)
# Out:
# 295397    2
# 296893    1
# 293446    1
# Name: NID, dtype: int64

# %%
qs_df.loc[(qs_df.NID==295397)&(qs_df.Year==2012)]
# Out:
#       City  Natural Sciences  Life Sciences And Medicine  \
# 726  PARIS               0.0                         0.0
# 743  PARIS               0.0                         0.0
#
#      Engineering And Technology  Arts And Humanities  International Students  \
# 726                         0.0                  0.0                    97.3
# 743                         0.0                  0.0                    97.3
#
#      Social Sciences And Management  Citations Per Faculty  Faculty Student  \
# 726                           29.12                    0.0              0.0
# 743                           29.12                    0.0              0.0
#
#      International Faculty  Academic Reputation  Employer Reputation Location  \
# 726                   98.4                  0.0                 98.5   FRANCE
# 743                   98.4                  0.0                 98.5   FRANCE
#
#         NID  Overall Score  Region                      University  Year
# 726  295397            NaN  EUROPE  HEC PARIS SCHOOL OF MANAGEMENT  2012
# 743  295397            NaN  EUROPE  HEC PARIS SCHOOL OF MANAGEMENT  2012

# %%
# Drop it
qs_df.drop_duplicates(subset=['NID', 'Year'], inplace=True)

# %%
qs_df.groupby('Year').agg({
    'Overall Score': lambda x: x.isna().sum(),
    'NID': ['count', 'nunique', 'size']
})
# Out:
#      Overall Score   NID
#           <lambda> count nunique  size
# Year
# 2012         368.0   865     865   865
# 2014         403.0   900     900   900
# 2015         388.0   885     885   885
# 2016         515.0   914     914   914
# 2017         533.0   933     933   933
# 2018         577.0   977     977   977
# 2019         515.0  1018    1018  1018
# 2020         570.0  1069    1069  1069
# 2021         684.0  1185    1185  1185
# 2022         799.0  1300    1300  1300

# %% [markdown]
# #### RE-CALCULATE OVERALL SCORE

# %%
qs_weights = {
    'labs': ['Academic Reputation', 'Employer Reputation', 'Faculty Student', 'Citations Per Faculty', 'International Students', 'International Faculty'],
    2021: [40, 10, 20, 20, 5, 5]
}

# %%
qs_df[qs_weights['labs']+['Year']].groupby('Year').apply(
    lambda tx: tx[qs_weights['labs']].isna().any(axis=1).sum()
)
# Out:
# Year
# 2012      1
# 2014      0
# 2015      0
# 2016    818
# 2017    793
# 2018    848
# 2019    520
# 2020    571
# 2021    690
# 2022     75
# dtype: int64

# %%
qs_df[qs_weights['labs']].describe()
# Out:
#        Academic Reputation  Employer Reputation  Faculty Student  \
# count          6938.000000           7065.00000      7523.000000
# mean             34.378221             36.25390        43.384554
# std              30.370608             30.80063        31.169069
# min               0.000000              0.00000         0.000000
# 25%               6.800000              6.90000        17.050000
# 50%              29.300000             32.10000        40.000000
# 75%              53.275000             57.90000        67.600000
# max             100.000000            100.00000       100.000000
#
#        Citations Per Faculty  International Students  International Faculty
# count            7442.000000             7465.000000            7385.000000
# mean               36.845834               40.619344              42.596886
# std                29.589601               33.407868              36.560410
# min                 0.000000                0.000000               0.000000
# 25%                 7.700000                8.600000               5.500000
# 50%                34.400000               35.400000              34.800000
# 75%                58.100000               68.300000              79.800000
# max               100.000000              100.000000             100.000000

# %%
sub_df = qs_df[
    qs_weights['labs']
].copy().fillna(0)

#res = np.ma.average(
#    np.ma.array(sub_df, mask=sub_df.isnull()),
#    axis=1,
#    weights=qs_weights.get(2021, qs_weights[2021])
#)

res = np.average(
    sub_df,
    axis=1,
    weights=qs_weights[2021]
)

qs_df.loc[
    :,
    'scores_overall_num'
] = np.round(res.data, 2)


qs_df.loc[:, 'scores_overall_calc'] = qs_df.groupby('Year').apply(
    lambda tx: (tx.scores_overall_num / tx.scores_overall_num.max() * 100).round(2)
).values

# %%
# Check calculations disrepancy
qs_df.groupby('Year').apply(
    lambda tx: (tx['Overall Score'] - tx.scores_overall_calc).abs().mean(skipna=True)
)
# Out:
# Year
# 2012    2.089557
# 2014    1.665976
# 2015    2.644044
# 2016    6.126190
# 2017    3.516925
# 2018    3.568700
# 2019    0.029145
# 2020    0.025371
# 2021    0.026347
# 2022    0.024950
# dtype: float64

# %% [markdown]
# #### Checking the disrepancies

# %%
qs_df.groupby('Year').apply(
    lambda tx: tx[qs_weights['labs']].isna().any(axis=1).sum()
)
# Out:
# Year
# 2012      1
# 2014      0
# 2015      0
# 2016    818
# 2017    793
# 2018    848
# 2019    520
# 2020    571
# 2021    690
# 2022     75
# dtype: int64

# %%
qs_df.loc[
    qs_df[qs_weights['labs']].isna().any(axis=1),
    qs_weights['labs'] + ['Year']
].groupby('Year').size()
# Out:
# Year
# 2012      1
# 2016    818
# 2017    793
# 2018    848
# 2019    520
# 2020    571
# 2021    690
# 2022     75
# dtype: int64

# %%
qs_df16 = qs_df[ (qs_df['Year']==2016)]

qs_df16['score_diff'] = (qs_df16['Overall Score'] - qs_df16['scores_overall_calc']).abs()
# Out:
# /home/d2ski/miniconda3/envs/vizlab/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
qs_df16.loc[
    qs_df16.score_diff>1,
    qs_weights['labs'] + ['Overall Score', 'scores_overall_calc', 'score_diff', 'NID']
           ].sort_values(by='score_diff', ascending=False)
# Out:
#       Academic Reputation  Employer Reputation  Faculty Student  \
# 3008                  NaN                  NaN              NaN
# 2881                  NaN                  NaN              NaN
# 3043                  NaN                 88.5              NaN
# 3002                  NaN                  NaN             78.5
# 3042                  NaN                 41.0              NaN
# 3030                  NaN                  NaN             70.1
# 2970                  NaN                  NaN             84.0
# 3009                  NaN                  NaN             47.0
# 3049                  NaN                  NaN             67.5
# 2935                  NaN                 60.6             72.8
# 2995                  NaN                  NaN             77.5
# 2951                  NaN                  NaN              NaN
# 2969                  NaN                  NaN             88.7
# 3041                  NaN                  NaN             76.4
# 3027                  NaN                  NaN              NaN
# 3037                  NaN                  NaN              NaN
# 2944                  NaN                 53.9              NaN
# 2892                  NaN                 78.6              NaN
# 2939                  NaN                  NaN              NaN
# 3038                  NaN                  NaN              NaN
# 2967                  NaN                  NaN              NaN
# 2914                  NaN                  NaN             48.8
# 2941                  NaN                  NaN             49.4
# 3040                  NaN                  NaN              NaN
# 2916                  NaN                 45.3              NaN
# 2950                  NaN                 79.4              NaN
# 3013                  NaN                 49.0              NaN
# 3019                  NaN                  NaN             99.9
# 3032                  NaN                  NaN              NaN
# 3001                  NaN                 49.0             48.1
# ...                   ...                  ...              ...
# 2693                 89.4                 86.6             78.5
# 2942                 38.4                 39.3              NaN
# 2864                 85.7                 54.4              NaN
# 2849                 47.2                 71.1              NaN
# 2722                 98.0                 75.0             46.1
# 2831                 65.3                 44.6             68.2
# 2756                 50.5                  NaN             84.2
# 2811                 95.9                 92.5             49.4
# 2688                 99.9                 96.6             94.1
# 2993                 36.8                 77.4             49.2
# 2708                 92.5                 80.9             86.8
# 2875                 41.6                 45.3              NaN
# 2791                 69.8                 64.7             85.8
# 2724                 86.0                 72.1             97.1
# 2837                 72.5                 68.6             51.3
# 2998                 35.5                 86.2             69.0
# 2897                 52.8                 45.0             53.4
# 2686                 99.2                 96.6             84.2
# 2842                 38.9                  NaN             99.9
# 2958                 36.5                 65.4             92.9
# 2682                 94.0                 81.1             92.3
# 2752                 85.7                 65.6             47.0
# 2983                 33.1                 46.0             56.9
# 2775                 71.5                 54.9             90.3
# 2767                 50.5                 57.3             99.4
# 2847                 42.2                 48.2             50.4
# 2882                 56.4                 48.7             42.2
# 2754                 78.4                 84.6             83.2
# 2729                 84.1                 45.7             81.7
# 2745                 87.1                 55.2             43.6
#
#       Citations Per Faculty  International Students  International Faculty  \
# 3008                    NaN                    89.1                   94.8
# 2881                   77.9                    98.0                   97.7
# 3043                    NaN                    50.8                   32.6
# 3002                    NaN                     NaN                    NaN
# 3042                    NaN                    92.1                   93.7
# 3030                    NaN                     NaN                    NaN
# 2970                    NaN                     NaN                   35.1
# 3009                    NaN                    54.6                   73.5
# 3049                    NaN                     NaN                    NaN
# 2935                    NaN                     NaN                   37.2
# 2995                    NaN                     NaN                   46.0
# 2951                   55.0                    99.7                   98.4
# 2969                    NaN                     NaN                   40.5
# 3041                    NaN                     NaN                    NaN
# 3027                   42.5                    79.0                   85.1
# 3037                   48.7                    45.5                   91.4
# 2944                   72.5                     NaN                   78.3
# 2892                   63.9                    69.6                   99.9
# 2939                   76.0                    97.8                   93.4
# 3038                   66.3                     NaN                   84.4
# 2967                   81.1                    44.3                   84.4
# 2914                   73.5                    66.0                    NaN
# 2941                   78.3                     NaN                    NaN
# 3040                   91.6                     NaN                    NaN
# 2916                   87.1                    36.1                   89.0
# 2950                   37.9                   100.0                   92.9
# 3013                   47.1                    88.7                   35.7
# 3019                    NaN                     NaN                    NaN
# 3032                   62.2                    67.8                   71.5
# 3001                    NaN                    58.8                   84.5
# ...                     ...                     ...                    ...
# 2693                  100.0                     NaN                    NaN
# 2942                   98.5                     NaN                   30.6
# 2864                   44.9                     NaN                    NaN
# 2849                   90.8                    87.4                   62.3
# 2722                   85.9                     NaN                    NaN
# 2831                   48.3                     NaN                    NaN
# 2756                   99.7                    87.1                   86.1
# 2811                    NaN                     NaN                    NaN
# 2688                   71.5                     NaN                    NaN
# 2993                    NaN                     NaN                   93.0
# 2708                   69.2                     NaN                    NaN
# 2875                   88.2                    91.7                   93.5
# 2791                   48.4                     NaN                    NaN
# 2724                   61.4                     NaN                    NaN
# 2837                   37.8                     NaN                    NaN
# 2998                    NaN                     NaN                    NaN
# 2897                   38.8                     NaN                   35.8
# 2686                   79.0                     NaN                   30.2
# 2842                   59.3                    77.8                   35.9
# 2958                    NaN                     NaN                    NaN
# 2682                   96.4                    51.7                    NaN
# 2752                   64.2                    75.8                    NaN
# 2983                   45.1                     NaN                    NaN
# 2775                   40.9                     NaN                   55.8
# 2767                   69.6                     NaN                  100.0
# 2847                   84.1                     NaN                   83.5
# 2882                   45.8                     NaN                   58.6
# 2754                   42.6                    39.2                    NaN
# 2729                   79.9                     NaN                   38.1
# 2745                   83.2                     NaN                   66.7
#
#       Overall Score  scores_overall_calc  score_diff     NID
# 3008           37.6                 9.22       28.38  294152
# 2881           49.3                25.42       23.88  297486
# 3043           35.5                13.05       22.45  294869
# 3002           38.0                15.73       22.27  294477
# 3042           35.5                13.42       22.08  294098
# 3030           36.1                14.05       22.05  294189
# 2970           40.4                18.60       21.80  297222
# 3009           37.5                15.83       21.67  294743
# 3049           35.0                13.53       21.47  297217
# 2935           43.7                22.53       21.17  294051
# 2995           38.8                17.84       20.96  294115
# 2951           41.9                20.95       20.95  294434
# 2969           40.4                19.80       20.60  294178
# 3041           35.6                15.31       20.29  294169
# 3027           36.2                16.74       19.46  297268
# 3037           35.9                16.62       19.28  297518
# 2944           42.8                23.85       18.95  297251
# 2892           48.0                29.18       18.82  297181
# 2939           43.1                24.81       18.29  297511
# 3038           35.8                17.52       18.28  294517
# 2967           40.4                22.71       17.69  297210
# 2914           45.5                27.82       17.68  294063
# 2941           43.0                25.60       17.40  297014
# 3040           35.7                18.36       17.34  294237
# 2916           45.5                28.26       17.24  294568
# 2950           42.4                25.22       17.18  294034
# 3013           37.4                20.59       16.81  294773
# 3019           36.8                20.02       16.78  295110
# 3032           36.0                19.44       16.56  297280
# 3001           38.1                21.73       16.37  294494
# ...             ...                  ...         ...     ...
# 2693           82.6                80.30        2.30  294124
# 2942           42.9                40.61        2.29  294454
# 2864           51.0                48.81        2.19  297489
# 2849           53.9                51.75        2.15  297208
# 2722           75.4                73.26        2.14  294804
# 2831           56.1                54.00        2.10  294394
# 2756           67.8                65.78        2.02  297437
# 2811           59.6                57.62        1.98  294835
# 2688           84.9                82.92        1.98  294111
# 2993           38.9                37.03        1.87  294620
# 2708           78.3                76.46        1.84  297628
# 2875           50.0                48.18        1.82  297293
# 2791           63.1                61.37        1.73  294258
# 2724           75.2                73.47        1.73  297250
# 2837           55.5                53.80        1.70  293977
# 2998           38.4                36.70        1.70  293373
# 2897           47.6                45.95        1.65  294314
# 2686           85.3                83.67        1.63  297403
# 2842           54.8                53.20        1.60  297494
# 2958           41.4                39.81        1.59  294618
# 2682           87.7                86.23        1.47  294767
# 2752           68.4                67.02        1.38  297218
# 2983           39.7                38.32        1.38  297178
# 2775           64.6                63.26        1.34  294329
# 2767           66.2                64.87        1.33  294476
# 2847           54.1                52.90        1.20  294761
# 2882           49.2                48.07        1.13  297022
# 2754           68.2                67.09        1.11  294121
# 2729           73.7                72.60        1.10  294836
# 2745           70.3                69.21        1.09  294071
#
# [286 rows x 10 columns]

# %%
qs_df.head(3)
# Out:
#         City  Natural Sciences  Life Sciences And Medicine  \
# 0  CAMBRIDGE             95.06                       60.89
# 1  CAMBRIDGE             98.50                       82.75
# 2  CAMBRIDGE            100.00                      100.00
#
#    Engineering And Technology  Arts And Humanities  International Students  \
# 0                      100.00                46.27                    96.5
# 1                       66.51                95.21                    96.0
# 2                       46.14               100.00                    78.4
#
#    Social Sciences And Management  Citations Per Faculty  Faculty Student  \
# 0                           64.62                   99.3             99.9
# 1                           72.97                   97.0             98.3
# 2                          100.00                  100.0             98.6
#
#    International Faculty  Academic Reputation  Employer Reputation  \
# 0                   86.4                100.0                100.0
# 1                   98.2                100.0                100.0
# 2                   90.0                100.0                100.0
#
#          Location     NID  Overall Score         Region  \
# 0   UNITED STATES  294850         100.00  NORTH AMERICA
# 1  UNITED KINGDOM  294561          99.78         EUROPE
# 2   UNITED STATES  294270          99.15  NORTH AMERICA
#
#                                     University  Year  scores_overall_num  \
# 0  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)  2012               98.98
# 1                      UNIVERSITY OF CAMBRIDGE  2012               98.77
# 2                           HARVARD UNIVERSITY  2012               98.14
#
#    scores_overall_calc
# 0               100.00
# 1                99.79
# 2                99.15

# %% [markdown]
# #### SAVE QS SCORES

# %%
# Save .csv
#qs_df.loc[
#    :,
#    ['Location', 'Region', 'University', 'NID', 'Year', 'scores_overall_calc'] + qs_weights['labs']
#].to_csv(DATASET_OUTPUT_DIR + 'qs_scores.csv')

# %% [markdown]
# ### MERGE DATA FROM ALL RANKINGS

# %%
the_df.head(3)
# Out:
#         location                                   name     nid rank  \
# 0  United States                     Harvard University     466    1
# 1  United States     California Institute of Technology  128779    2
# 2  United States  Massachusetts Institute of Technology     471    3
#
#    scores_citations  scores_citations_rank  scores_industry_income  \
# 0         98.800003                      8               34.500000
# 1         99.900002                      1               83.699997
# 2         99.900002                      2               87.500000
#
#    scores_industry_income_rank  scores_international_outlook  \
# 0                          105                     72.400002
# 1                           24                     54.599998
# 2                           21                     82.300003
#
#    scores_international_outlook_rank  ... scores_research_rank  \
# 0                                 49  ...                    2
# 1                                 93  ...                    4
# 2                                 36  ...                   11
#
#    scores_teaching  scores_teaching_rank  year  stats_female_male_ratio  \
# 0        99.699997                     1  2011                      NaN
# 1        97.699997                     4  2011                      NaN
# 2        97.800003                     3  2011                      NaN
#
#    stats_number_students  stats_pc_intl_students stats_student_staff_ratio  \
# 0                    NaN                     NaN                       NaN
# 1                    NaN                     NaN                       NaN
# 2                    NaN                     NaN                       NaN
#
#   scores_overall_num scores_overall_calc
# 0               96.1               96.11
# 1               96.0               96.00
# 2               95.6               95.53
#
# [3 rows x 23 columns]

# %%
arwu_df.head(3)
# Out:
#    Alumni  Award   HiCi    N&S   PCP    PUB ranking          region  \
# 0    98.6  100.0  100.0  100.0  60.6  100.0       1   United States
# 1    41.2   72.2   96.1   75.2  68.1   72.3       2   United States
# 2   100.0   93.4   56.6   58.5  73.2   70.2       3  United Kingdom
#
#   regionLogo regionRanking  score               univNameEn  \
# 0         us             1  100.0       Harvard University
# 1         us             2   77.2      Stanford University
# 2         gb             1   76.2  University of Cambridge
#
#                     univUp  year  scores_overall_num  scores_overall_calc
# 0       harvard-university  2004               95.92                100.0
# 1      stanford-university  2004               74.09                 77.2
# 2  university-of-cambridge  2004               73.06                 76.2

# %%
qs_df.head(3)
# Out:
#         City  Natural Sciences  Life Sciences And Medicine  \
# 0  CAMBRIDGE             95.06                       60.89
# 1  CAMBRIDGE             98.50                       82.75
# 2  CAMBRIDGE            100.00                      100.00
#
#    Engineering And Technology  Arts And Humanities  International Students  \
# 0                      100.00                46.27                    96.5
# 1                       66.51                95.21                    96.0
# 2                       46.14               100.00                    78.4
#
#    Social Sciences And Management  Citations Per Faculty  Faculty Student  \
# 0                           64.62                   99.3             99.9
# 1                           72.97                   97.0             98.3
# 2                          100.00                  100.0             98.6
#
#    International Faculty  Academic Reputation  Employer Reputation  \
# 0                   86.4                100.0                100.0
# 1                   98.2                100.0                100.0
# 2                   90.0                100.0                100.0
#
#          Location     NID  Overall Score         Region  \
# 0   UNITED STATES  294850         100.00  NORTH AMERICA
# 1  UNITED KINGDOM  294561          99.78         EUROPE
# 2   UNITED STATES  294270          99.15  NORTH AMERICA
#
#                                     University  Year  scores_overall_num  \
# 0  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)  2012               98.98
# 1                      UNIVERSITY OF CAMBRIDGE  2012               98.77
# 2                           HARVARD UNIVERSITY  2012               98.14
#
#    scores_overall_calc
# 0               100.00
# 1                99.79
# 2                99.15

# %% [markdown]
# #### ADD COUNTRY COLUMN

# %%
# Unify country names
countries = np.union1d(
    the_df.location.str.lower(),
    np.union1d(arwu_df.region.str.lower(), qs_df.Location.str.lower())
)

failed = []
country_map = {}

for loc in countries:
    try:
        country = pycountry.countries.search_fuzzy(loc)
        country_map[loc] = country[0].name
    except LookupError as e:
        failed.append(loc)

# %%
failed
# Out:
# ['china (mainland)',
#  'china-hong kong',
#  'china-macau',
#  'china-taiwan',
#  'macau sar',
#  'northern cyprus',
#  'palestinian territory, occupied',
#  'south korea']

# %%
failed_add = [
    'China',
    'Hong Kong',
    'Macao',
    'Taiwan, Province of China',
    'Macao',
    'Cyprus',
    'Palestine, State of',
    'Korea, Republic of'
]

for loc, country in zip(failed, failed_add):
    country_map[loc] = country
    
country_map['hong kong sar'] = 'Hong Kong'

# %%
the_df.loc[:, 'Country'] = the_df.location.str.lower().apply(lambda x: country_map[x])
arwu_df.loc[:, 'Country'] = arwu_df.region.str.lower().apply(lambda x: country_map[x])
qs_df.loc[:, 'Country'] = qs_df.Location.str.lower().apply(lambda x: country_map[x])

# %% [markdown]
# #### MERGE

# %%
the_scores = the_df[['Country', 'year', 'scores_overall_num', 'name']].copy().rename(
    columns = {
    'year': 'Year',
    'scores_overall_num': 'Score',
    'name': 'University',
})

the_scores.loc[:, 'Source'] = 'THE'

# %%
arwu_scores = arwu_df[['Country', 'year', 'scores_overall_calc', 'univNameEn']].copy().rename(
    columns = {
    'year': 'Year',
    'scores_overall_calc': 'Score',
    'univNameEn': 'University',
})

arwu_scores.loc[:, 'Source'] = 'ARWU'

arwu_scores.loc[:, 'Year'] = arwu_scores.loc[:, 'Year'] + 1

# %%
qs_scores = qs_df[['Country', 'Year', 'scores_overall_calc', 'University']].copy().rename(
    columns = {
    'scores_overall_calc': 'Score',
})

qs_scores.loc[:, 'Source'] = 'QS'

# %% [markdown]
# #### MERGE AND SUBSET TOP-500 UNIVERSITIES BY SCORE RANK IN EVERY RANKING

# %%
scores = pd.concat([
    the_scores,
    arwu_scores,
    qs_scores
], ignore_index=True)

# %%
scores.loc[
    :,
    'Rank'
] = scores.groupby(['Source', 'Year'])['Score'].rank(method='first', ascending=False)

# %%
scores.head(10)
# Out:
#           Country  Year  Score                             University Source  \
# 0   United States  2011   96.1                     Harvard University    THE
# 1   United States  2011   96.0     California Institute of Technology    THE
# 2   United States  2011   95.6  Massachusetts Institute of Technology    THE
# 3   United States  2011   94.3                    Stanford University    THE
# 4   United States  2011   94.2                   Princeton University    THE
# 5  United Kingdom  2011   91.2                   University of Oxford    THE
# 6  United Kingdom  2011   91.2                University of Cambridge    THE
# 7   United States  2011   91.1     University of California, Berkeley    THE
# 8  United Kingdom  2011   90.6                Imperial College London    THE
# 9   United States  2011   89.5                        Yale University    THE
#
#    Rank
# 0   1.0
# 1   2.0
# 2   3.0
# 3   4.0
# 4   5.0
# 5   6.0
# 6   7.0
# 7   8.0
# 8   9.0
# 9  10.0

# %%
# Data from 2014 only
scores = scores.loc[ scores.Year >= 2014]

# %%
# Score stats
scores.groupby(['Year', 'Source']).agg({
    'Score': 'sum',
    'University': 'count',
    'Rank': 'max'
})
# Out:
#                 Score  University    Rank
# Year Source
# 2014 ARWU     9338.70         500   500.0
#      QS      27668.50         900   900.0
#      THE     18850.29         400   400.0
# 2015 ARWU     9415.80         500   500.0
#      QS      28215.89         885   885.0
#      THE     19521.72         401   401.0
# 2016 ARWU     9386.50         500   500.0
#      QS      26058.77         914   914.0
#      THE     30501.37         800   800.0
# 2017 ARWU     9626.50         500   500.0
#      QS      25099.06         933   933.0
#      THE     35438.67         981   981.0
# 2018 ARWU    12437.80         800   800.0
#      QS      25464.83         977   977.0
#      THE     39348.04        1103  1103.0
# 2019 ARWU    13808.70        1000  1000.0
#      QS      27596.56        1018  1018.0
#      THE     44226.02        1258  1258.0
# 2020 ARWU    14181.20        1000  1000.0
#      QS      27695.67        1069  1069.0
#      THE     48587.43        1397  1397.0
# 2021 ARWU    14160.20         999   999.0
#      QS      27981.62        1185  1185.0
#      THE     52697.47        1526  1526.0
# 2022 ARWU    14426.40        1000  1000.0
#      QS      32772.09        1300  1300.0
#      THE     56959.69        2112  2112.0

# %%
# TOP-500 universities only
scores500 = scores.loc[
    scores.Rank <= 500
]

# %%
# Aggregate by country
country_scores500 = scores500.groupby(['Country', 'Year', 'Source'])

country_scores500_data = pd.DataFrame({
    'RankPct': country_scores500['Rank'].count() / country_scores500['Rank'].max() * 100,
    'RankCount': country_scores500['Rank'].count(),
    'RankMean': country_scores500['Rank'].mean(),
    'RankMedian': country_scores500['Rank'].median(),
}).reset_index().round(0)

# %%
# Check USA
country_scores500_data.loc[
    country_scores500_data.Country == 'United States'
].sort_values(by=['Source', 'Year'])
# Out:
#             Country  Year Source  RankPct  RankCount  RankMean  RankMedian
# 1305  United States  2014   ARWU     30.0        149     195.0       172.0
# 1308  United States  2015   ARWU     30.0        146     202.0       178.0
# 1311  United States  2016   ARWU     30.0        146     204.0       185.0
# 1314  United States  2017   ARWU     28.0        137     199.0       186.0
# 1317  United States  2018   ARWU     27.0        135     199.0       188.0
# 1320  United States  2019   ARWU     28.0        139     213.0       207.0
# 1323  United States  2020   ARWU     28.0        137     214.0       215.0
# 1326  United States  2021   ARWU     27.0        133     212.0       204.0
# 1329  United States  2022   ARWU     26.0        129     211.0       205.0
# 1306  United States  2014     QS     21.0        104     225.0       201.0
# 1309  United States  2015     QS     19.0         97     216.0       192.0
# 1312  United States  2016     QS     19.0         93     215.0       172.0
# 1315  United States  2017     QS     19.0         95     219.0       182.0
# 1318  United States  2018     QS     18.0         89     213.0       182.0
# 1321  United States  2019     QS     19.0         93     216.0       196.0
# 1324  United States  2020     QS     18.0         90     216.0       200.0
# 1327  United States  2021     QS     17.0         86     211.0       172.0
# 1330  United States  2022     QS     17.0         87     216.0       187.0
# 1307  United States  2014    THE     28.0        109     153.0       135.0
# 1310  United States  2015    THE     28.0        108     156.0       142.0
# 1313  United States  2016    THE     25.0        122     201.0       190.0
# 1316  United States  2017    THE     24.0        120     198.0       184.0
# 1319  United States  2018    THE     25.0        125     209.0       202.0
# 1322  United States  2019    THE     25.0        123     211.0       216.0
# 1325  United States  2020    THE     24.0        121     212.0       210.0
# 1328  United States  2021    THE     24.0        117     208.0       197.0
# 1331  United States  2022    THE     22.0        109     204.0       184.0

# %% [markdown]
# #### SAVE DATA FOR VISUALIZATION

# %%
scores500.to_csv(VIZ_DATA_DIR + 'scores500.csv', index=False)
country_scores500_data.to_csv(VIZ_DATA_DIR + 'country_scores500.csv', index=False)
