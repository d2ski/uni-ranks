# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ### EXPLORING DATA

# %%
with open('../data_raw/the_data/2012.json') as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data['data'])

# %%
# Select columns with data indicators and university data
sel_cols = df.columns[
    df.columns.str.contains('scores_') | \
    df.columns.str.contains('stats_') | \
    df.columns.isin(['name', 'rank', 'nid', 'location'])
]

# %%
df[sel_cols].head()
# Out:
#          location                                name     nid rank  \
# 0   United States  California Institute of Technology  128779    1
# 1   United States                  Harvard University     466    2
# 2   United States                 Stanford University     467    2
# 3  United Kingdom                University of Oxford     468    4
# 4   United States                Princeton University     469    5
#
#   scores_citations scores_citations_rank scores_industry_income  \
# 0             99.9                     3                   97.0
# 1             99.8                     7                   35.9
# 2             99.8                     8                   63.8
# 3             97.9                    15                   62.1
# 4            100.0                     2                   81.0
#
#   scores_industry_income_rank scores_international_outlook  \
# 0                          26                         56.0
# 1                         212                         67.5
# 2                          74                         57.2
# 3                          81                         91.9
# 4                          43                         49.6
#
#   scores_international_outlook_rank scores_overall scores_overall_rank  \
# 0                               172           94.8                   1
# 1                               115           93.9                   2
# 2                               162           93.9                   3
# 3                                12           93.6                   4
# 4                               198           92.9                   5
#
#   scores_research scores_research_rank scores_teaching scores_teaching_rank
# 0            98.2                    4            95.7                    2
# 1            97.4                    5            95.8                    1
# 2            98.9                    3            94.8                    3
# 3            96.6                    6            89.5                    8
# 4            99.1                    2            91.5                    6

# %%
df[sel_cols].tail()
# Out:
#           location                                    name  nid     rank  \
# 397      Australia                     La Trobe University  835  350-400
# 398  United States                Georgia State University  824  350-400
# 399  United States                 Old Dominion University  847  350-400
# 400          Spain                  University of Zaragoza  866  350-400
# 401        Ireland  National University of Ireland, Galway  842  350-400
#
#     scores_citations scores_citations_rank scores_industry_income  \
# 397             13.6                   395                   28.9
# 398             34.4                   326                   39.1
# 399             46.9                   253                      -
# 400             38.4                   303                   42.9
# 401             31.3                   337                   32.7
#
#     scores_industry_income_rank scores_international_outlook  \
# 397                         307                         71.3
# 398                         180                         27.9
# 399                         383                         27.3
# 400                         142                         28.8
# 401                         254                         72.6
#
#     scores_international_outlook_rank scores_overall scores_overall_rank  \
# 397                                96              -                 252
# 398                               316              -                 232
# 399                               319              -                 279
# 400                               312              -                 389
# 401                                89              -                 273
#
#     scores_research scores_research_rank scores_teaching scores_teaching_rank
# 397            19.5                  297            19.0                  351
# 398            20.2                  287            19.6                  344
# 399            12.5                  378            17.1                  374
# 400             9.3                  399            14.5                  392
# 401            12.2                  384            17.9                  363

# %% [markdown]
# ### MAKING THE DATASET - PROCEDURE

# %%
dataset = []

for year in range(2011, 2023):
    filename = '../data_raw/the_data/{year}.json'.format(year=year)
    print('Processing:', filename)
    
    with open(filename) as f:
        data = json.load(f)
    
    df = pd.DataFrame(data['data'])
    
    sel_cols = df.columns[
        df.columns.str.contains('scores_') | \
        df.columns.str.contains('stats_') | \
        df.columns.isin(['name', 'rank', 'nid', 'location'])
    ]
    
    sub_data = df[sel_cols]
    
    sub_data.loc[:, 'year'] = year
    
    dataset.append(sub_data)
# Out:
# Processing: the_data/2011.json
# Processing: the_data/2012.json
# Processing: the_data/2013.json
# Processing: the_data/2014.json
# Processing: the_data/2015.json
# Processing: the_data/2016.json
# Processing: the_data/2017.json
# Processing: the_data/2018.json
# Processing: the_data/2019.json
# Processing: the_data/2020.json
# Processing: the_data/2021.json
# Processing: the_data/2022.json

# %%
dataset_df = pd.concat(dataset, ignore_index=True, sort=False)

# %%
dataset_df.head(3)
# Out:
#         location                                   name     nid rank  \
# 0  United States                     Harvard University     466    1
# 1  United States     California Institute of Technology  128779    2
# 2  United States  Massachusetts Institute of Technology     471    3
#
#   scores_citations scores_citations_rank scores_industry_income  \
# 0             98.8                     8                   34.5
# 1             99.9                     1                   83.7
# 2             99.9                     2                   87.5
#
#   scores_industry_income_rank scores_international_outlook  \
# 0                         105                         72.4
# 1                          24                         54.6
# 2                          21                         82.3
#
#   scores_international_outlook_rank  ... scores_overall_rank scores_research  \
# 0                                49  ...                   1            98.7
# 1                                93  ...                   2            98.0
# 2                                36  ...                   3            91.4
#
#   scores_research_rank scores_teaching scores_teaching_rank  year  \
# 0                    2            99.7                    1  2011
# 1                    4            97.7                    4  2011
# 2                   11            97.8                    3  2011
#
#    stats_female_male_ratio stats_number_students stats_pc_intl_students  \
# 0                      NaN                   NaN                    NaN
# 1                      NaN                   NaN                    NaN
# 2                      NaN                   NaN                    NaN
#
#   stats_student_staff_ratio
# 0                       NaN
# 1                       NaN
# 2                       NaN
#
# [3 rows x 21 columns]

# %%
dataset_df.loc[ dataset_df.nid==466]
# Out:
#            location                name  nid rank scores_citations  \
# 0     United States  Harvard University  466    1             98.8
# 201   United States  Harvard University  466    2             99.8
# 605   United States  Harvard University  466    4             99.2
# 1003  United States  Harvard University  466    2             99.1
# 1403  United States  Harvard University  466    2             98.9
# 1808  United States  Harvard University  466    6             99.8
# 2608  United States  Harvard University  466    6             99.7
# 3589  United States  Harvard University  466    6             99.7
# 4692  United States  Harvard University  466    6             99.6
# 5951  United States  Harvard University  466    7             99.1
# 7344  United States  Harvard University  466    3             99.4
# 8870  United States  Harvard University  466   =2             99.2
#
#      scores_citations_rank scores_industry_income scores_industry_income_rank  \
# 0                        8                   34.5                         105
# 201                      7                   35.9                         212
# 605                     10                   39.9                         212
# 1003                     9                   40.6                         208
# 1403                    12                   44.0                         184
# 1808                     5                   45.2                         276
# 2608                     8                   47.3                         287
# 3589                     8                   46.4                         330
# 4692                     8                   48.7                         345
# 5951                    19                   47.3                         395
# 7344                    22                   46.8                         421
# 8870                    19                   48.9                         418
#
#      scores_international_outlook scores_international_outlook_rank  ...  \
# 0                            72.4                                49  ...
# 201                          67.5                               115  ...
# 605                          63.7                               128  ...
# 1003                         66.2                               125  ...
# 1403                         67.6                               115  ...
# 1808                         77.2                               134  ...
# 2608                         77.9                               139  ...
# 3589                         79.7                               143  ...
# 4692                         79.7                               164  ...
# 5951                         76.3                               217  ...
# 7344                         77.7                               218  ...
# 8870                         79.8                               209  ...
#
#      scores_overall_rank scores_research scores_research_rank scores_teaching  \
# 0                      1            98.7                    2            99.7
# 201                    2            97.4                    5            95.8
# 605                    4            98.6                    5            94.9
# 1003                   2            98.5                    1            95.3
# 1403                   2            98.6                    1            92.9
# 1808                   6              99                    1            83.6
# 2608                  60            98.3                    2            87.5
# 3589                  60            98.4                    2            84.2
# 4692                  60            98.4                    3            90.1
# 5951                  70            98.6                    3            89.2
# 7344                  30            98.8                    3            94.4
# 8870                  30            98.9                    3            94.5
#
#      scores_teaching_rank  year  stats_female_male_ratio  \
# 0                       1  2011                      NaN
# 201                     1  2012                      NaN
# 605                     3  2013                      NaN
# 1003                    1  2014                      NaN
# 1403                    1  2015                      NaN
# 1808                   10  2016                     None
# 2608                    9  2017                     None
# 3589                    9  2018                     None
# 4692                    8  2019                  48 : 52
# 5951                    8  2020                  49 : 51
# 7344                    1  2021                  49 : 51
# 8870                    1  2022                  50 : 50
#
#      stats_number_students stats_pc_intl_students stats_student_staff_ratio
# 0                      NaN                    NaN                       NaN
# 201                    NaN                    NaN                       NaN
# 605                    NaN                    NaN                       NaN
# 1003                   NaN                    NaN                       NaN
# 1403                   NaN                    NaN                       NaN
# 1808                20,152                    25%                       8.9
# 2608                19,890                    25%                       8.8
# 3589                20,326                    26%                       8.9
# 4692                20,595                    26%                       9.1
# 5951                20,823                    24%                       9.2
# 7344                21,261                    25%                       9.3
# 8870                21,574                    24%                       9.5
#
# [12 rows x 21 columns]

# %%
dataset_df.to_csv('../data_raw/THE_World_Rankings.csv')
