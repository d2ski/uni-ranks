# %%
import pandas as pd
import json

# %% [markdown]
# ### EXPLORING DATA

# %%
filename = '../data_raw/arwu_data/2017.json'
with open(filename) as f:
    data = json.load(f)
    
data = data['data']

# %%
# https://www.shanghairanking.com/methodology/arwu/2021
data['indicators']
# Out:
# [{'code': '84', 'nameEn': 'Alumni'},
#  {'code': '85', 'nameEn': 'Award'},
#  {'code': '86', 'nameEn': 'HiCi'},
#  {'code': '87', 'nameEn': 'N&S'},
#  {'code': '88', 'nameEn': 'PUB'},
#  {'code': '89', 'nameEn': 'PCP'}]

# %%
indicators = { rec['code']:rec['nameEn'] for rec in data['indicators'] }

# %%
indicators
# Out:
# {'84': 'Alumni',
#  '85': 'Award',
#  '86': 'HiCi',
#  '87': 'N&S',
#  '88': 'PUB',
#  '89': 'PCP'}

# %%
ind_df = pd.DataFrame(
    [ { indicators[k]: v for k,v in rec['indData'].items()} for rec in data['rankings'] ]
)

# %%
uni_df = pd.DataFrame(
    data['rankings'],
    columns = [
        'ranking',
        'univNameEn',
        'univUp',
        'region',
        'regionLogo',
        'regionRanking',
        'score',
    ]
)

# %%
df = pd.concat([uni_df, ind_df], axis=1)

# %%
df.head()
# Out:
#   ranking                                   univNameEn  \
# 0       1                           Harvard University
# 1       2                          Stanford University
# 2       3                      University of Cambridge
# 3       4  Massachusetts Institute of Technology (MIT)
# 4       5           University of California, Berkeley
#
#                                       univUp          region regionLogo  \
# 0                         harvard-university   United States         us
# 1                        stanford-university   United States         us
# 2                    university-of-cambridge  United Kingdom         gb
# 3  massachusetts-institute-of-technology-mit   United States         us
# 4          university-of-california-berkeley   United States         us
#
#   regionRanking  score  Alumni  Award   HiCi    N&S   PCP    PUB
# 0             1  100.0   100.0  100.0  100.0  100.0  79.5  100.0
# 1             2   76.5    44.5   88.5   87.3   74.4  56.8   73.7
# 2             1   70.9    81.4   95.4   54.6   57.3  59.1   69.8
# 3             3   70.4    68.7   82.3   56.7   72.4  70.8   63.5
# 4             4   69.1    64.4   78.4   63.6   68.1  58.7   66.7

# %% [markdown]
# ### MAKING THE DATASET - PROCEDURE

# %%
dataset_df = pd.DataFrame([])

for year in range(2003, 2022):
    filename = '../data_raw/arwu_data/{year}.json'.format(year=year)
    print('Processing:', filename)
    
    with open(filename) as f:
        data = json.load(f)
        
    data = data['data']
    
    indicators = { rec['code']:rec['nameEn'] for rec in data['indicators'] }
    
    ind_df = pd.DataFrame(
        [ { indicators[k]: v for k,v in rec['indData'].items()} for rec in data['rankings'] ]
    )
    
    sel_cols = [ 'ranking', 'univNameEn', 'univUp', 'region', 'regionLogo', 'regionRanking', 'score' ]
    
    uni_df = pd.DataFrame(
        data['rankings'],
        columns = sel_cols
    )
    
    df = pd.concat([uni_df, ind_df], axis=1)
    df.loc[:, 'year'] = year
    
    dataset_df = pd.concat([dataset_df, df])
# Out:
# Processing: arwu_data/2003.json
# Processing: arwu_data/2004.json
# Processing: arwu_data/2005.json
# /home/d2ski/miniconda3/envs/vizlab/lib/python3.7/site-packages/ipykernel_launcher.py:28: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# Processing: arwu_data/2006.json
# Processing: arwu_data/2007.json
# Processing: arwu_data/2008.json
# Processing: arwu_data/2009.json
# Processing: arwu_data/2010.json
# Processing: arwu_data/2011.json
# Processing: arwu_data/2012.json
# Processing: arwu_data/2013.json
# Processing: arwu_data/2014.json
# Processing: arwu_data/2015.json
# Processing: arwu_data/2016.json
# Processing: arwu_data/2017.json
# Processing: arwu_data/2018.json
# Processing: arwu_data/2019.json
# Processing: arwu_data/2020.json
# Processing: arwu_data/2021.json

# %%
dataset_df.head()
# Out:
#    Alumni  Award   HiCi    N&S    PCP    PUB ranking          region  \
# 0     NaN  100.0  100.0  100.0   68.7  100.0       1   United States
# 1     NaN   76.2   88.2   73.8   80.5   72.2       2   United States
# 2     NaN   72.9   68.0   64.1  100.0   52.0       3   United States
# 3     NaN   75.0   70.3   76.1   51.8   72.8       4   United States
# 4     NaN   91.1   58.0   56.4   68.7   69.3       5  United Kingdom
#
#   regionLogo regionRanking  score                          univNameEn  \
# 0         us             1  100.0                  Harvard University
# 1         us             2   83.5                 Stanford University
# 2         us             3   76.3  California Institute of Technology
# 3         us             4   74.0  University of California, Berkeley
# 4         gb             1   73.4             University of Cambridge
#
#                                univUp  year
# 0                  harvard-university  2003
# 1                 stanford-university  2003
# 2  california-institute-of-technology  2003
# 3   university-of-california-berkeley  2003
# 4             university-of-cambridge  2003

# %%
dataset_df.tail()
# Out:
#      Alumni  Award  HiCi  N&S   PCP   PUB   ranking         region regionLogo  \
# 995     0.0    0.0   0.0  2.5  11.1  26.9  901-1000         Poland         pl
# 996    17.7    0.0   0.0  5.0  16.6  11.2  901-1000  United States         us
# 997     0.0    0.0   0.0  3.5  10.7  25.4  901-1000         Poland         pl
# 998     0.0    0.0   0.0  2.0   9.5  25.6  901-1000          China         cn
# 999     0.0    0.0   7.3  1.4   9.0  20.6  901-1000          China         cn
#
#     regionRanking  score                                    univNameEn  \
# 995          8-10    NaN               Warsaw University of Technology
# 996       187-200    NaN                              Williams College
# 997          8-10    NaN  Wroclaw University of Science and Technology
# 998       143-157    NaN    Wuhan University of Science and Technology
# 999       143-157    NaN                             Yantai University
#
#                                            univUp  year
# 995               warsaw-university-of-technology  2021
# 996                              williams-college  2021
# 997  wroclaw-university-of-science-and-technology  2021
# 998    wuhan-university-of-science-and-technology  2021
# 999                             yantai-university  2021

# %%
dataset_df.to_csv('../data_raw/ARWU_World_Rankings.csv')
