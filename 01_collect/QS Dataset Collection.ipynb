# %%
import pandas as pd
import numpy as np
import json
import re

# %%
# !pip install beautifulsoup4
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/d2ski/miniconda3/envs/vizlab/lib/python3.7/site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /home/d2ski/miniconda3/envs/vizlab/lib/python3.7/site-packages (from beautifulsoup4) (2.2.1)

# %% [markdown]
# ### EXPLORING THE DATA

# %%
filename = '../data_raw/qs_data/2022.txt'
with open(filename) as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data['data'])

# %% [markdown]
# #### SUBSET AND RENAME COLUMNS

# %%
# Select columns with data indicators and university data
sel_cols = df.columns[
    df.columns.str.contains('ind_') | df.columns.isin(['nid', 'uni', 'region', 'location', 'city', 'overall'])
]

# %%
def parse_col_name(x):
    soup = BeautifulSoup(x)
    tag = soup.find('div', class_="td-wrap")
    if tag:
        return tag.text.strip().title()
    
    return x.strip().title()

# %%
data_columns = {
    'nid': 'NID'
}
for col_raw in data['columns']:
    if col_raw['data'] in sel_cols:
        data_columns[col_raw['data']] = parse_col_name(col_raw['title'])

# %%
data_columns
# Out:
# {'nid': 'NID',
#  'region': 'Region',
#  'location': 'Location',
#  'uni': 'University',
#  'overall': 'Overall Score',
#  'city': 'City',
#  'ind_14': 'International Students Ratio',
#  'ind_18': 'International Faculty Ratio',
#  'ind_36': 'Faculty Student Ratio',
#  'ind_73': 'Citations Per Faculty',
#  'ind_76': 'Academic Reputation',
#  'ind_77': 'Employer Reputation'}

# %%
sub_data = df[sel_cols]
sub_data.columns = sub_data.columns.map(lambda x: data_columns[x])

# %%
sub_data.head()
# Out:
#         City                       International Students Ratio  \
# 0  Cambridge  <div class="td-wrap"><div class="td-wrap-in">9...
# 1     Oxford  <div class="td-wrap"><div class="td-wrap-in">9...
# 2   Stanford  <div class="td-wrap"><div class="td-wrap-in">6...
# 3  Cambridge  <div class="td-wrap"><div class="td-wrap-in">9...
# 4  Cambridge  <div class="td-wrap"><div class="td-wrap-in">7...
#
#                          International Faculty Ratio  \
# 0  <div class="td-wrap"><div class="td-wrap-in">1...
# 1  <div class="td-wrap"><div class="td-wrap-in">9...
# 2  <div class="td-wrap"><div class="td-wrap-in">9...
# 3  <div class="td-wrap"><div class="td-wrap-in">1...
# 4  <div class="td-wrap"><div class="td-wrap-in">8...
#
#                                Faculty Student Ratio  \
# 0  <div class="td-wrap"><div class="td-wrap-in">1...
# 1  <div class="td-wrap"><div class="td-wrap-in">1...
# 2  <div class="td-wrap"><div class="td-wrap-in">1...
# 3  <div class="td-wrap"><div class="td-wrap-in">1...
# 4  <div class="td-wrap"><div class="td-wrap-in">9...
#
#                                Citations Per Faculty  \
# 0  <div class="td-wrap"><div class="td-wrap-in">1...
# 1  <div class="td-wrap"><div class="td-wrap-in">9...
# 2  <div class="td-wrap"><div class="td-wrap-in">9...
# 3  <div class="td-wrap"><div class="td-wrap-in">9...
# 4  <div class="td-wrap"><div class="td-wrap-in">1...
#
#                                  Academic Reputation  \
# 0  <div class="td-wrap"><div class="td-wrap-in">1...
# 1  <div class="td-wrap"><div class="td-wrap-in">1...
# 2  <div class="td-wrap"><div class="td-wrap-in">1...
# 3  <div class="td-wrap"><div class="td-wrap-in">1...
# 4  <div class="td-wrap"><div class="td-wrap-in">1...
#
#                                  Employer Reputation        Location     NID  \
# 0  <div class="td-wrap"><div class="td-wrap-in">1...   United States  294850
# 1  <div class="td-wrap"><div class="td-wrap-in">1...  United Kingdom  294654
# 2  <div class="td-wrap"><div class="td-wrap-in">1...   United States  297282
# 3  <div class="td-wrap"><div class="td-wrap-in">1...  United Kingdom  294561
# 4  <div class="td-wrap"><div class="td-wrap-in">1...   United States  294270
#
#                                        Overall Score         Region  \
# 0  <div class="td-wrap"><div class="td-wrap-in">1...  North America
# 1  <div class="td-wrap"><div class="td-wrap-in">9...         Europe
# 2  <div class="td-wrap"><div class="td-wrap-in">9...  North America
# 3  <div class="td-wrap"><div class="td-wrap-in">9...         Europe
# 4  <div class="td-wrap"><div class="td-wrap-in">9...  North America
#
#                                           University
# 0  <div class="td-wrap"><div class="td-wrap-in"><...
# 1  <div class="td-wrap"><div class="td-wrap-in"><...
# 2  <div class="td-wrap"><div class="td-wrap-in"><...
# 3  <div class="td-wrap"><div class="td-wrap-in"><...
# 4  <div class="td-wrap"><div class="td-wrap-in"><...

# %% [markdown]
# #### PARSE DATA VALUES

# %%
def parse_value(x):
    soup = BeautifulSoup(x)
    tag = soup.find('div', class_="td-wrap-in")
    if tag:
        return tag.text.strip().upper()
    
    return x.strip().upper()

# %%
sub_data = sub_data.applymap(parse_value)

# %%
sub_data.head(3)
# Out:
#         City International Students Ratio International Faculty Ratio  \
# 0  CAMBRIDGE                         91.4                         100
# 1     OXFORD                         98.5                        99.5
# 2   STANFORD                           67                        99.8
#
#   Faculty Student Ratio Citations Per Faculty Academic Reputation  \
# 0                   100                   100                 100
# 1                   100                    96                 100
# 2                   100                  99.9                 100
#
#   Employer Reputation        Location     NID Overall Score         Region  \
# 0                 100   UNITED STATES  294850           100  NORTH AMERICA
# 1                 100  UNITED KINGDOM  294654          99.5         EUROPE
# 2                 100   UNITED STATES  297282          98.7  NORTH AMERICA
#
#                                     University
# 0  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)
# 1                         UNIVERSITY OF OXFORD
# 2                          STANFORD UNIVERSITY

# %% [markdown]
# ### MAKING THE DATASET PROCEDURE

# %%
def parse_col_name(x):
    soup = BeautifulSoup(x)
    tag = soup.find('div', class_="td-wrap")
    if tag:
        return tag.text.strip().title()
    
    return x.strip().title()

def parse_value(x):
    soup = BeautifulSoup(x)
    tag = soup.find('div', class_="td-wrap-in")
    if tag:
        return tag.text.strip().upper()
    
    return x.strip().upper()

# %%
years = [
    2012,
    2014,
    2015,
    2016,
    2017,
    2018,
    2019,
    2020,
    2021,
    2022
]

# %%
dataset = []

for year in years:
    
    filename = '../data_raw/qs_data/{year}.txt'.format(year=year)
    
    print('Processing:', filename)
    
    # Load data
    with open(filename) as f:
        data = json.load(f)
    df = pd.DataFrame(data['data'])
    
    # Select columns with data indicators and university data
    sel_cols = df.columns[
        df.columns.str.contains('ind_') | df.columns.isin(['nid', 'uni', 'region', 'location', 'city', 'overall'])
    ]
    
    # Columns dictionary
    data_columns = {
        'nid': 'NID'
    }
    for col_raw in data['columns']:
        if col_raw['data'] in sel_cols:
            data_columns[col_raw['data']] = parse_col_name(col_raw['title'])
            
    # Subset data
    sub_data = df[sel_cols]
    sub_data.columns = sub_data.columns.map(lambda x: data_columns[x])
    
    # Unify column names
    sub_data.columns = sub_data.columns.map(lambda x: x.replace('&', 'And'))
    sub_data.columns = sub_data.columns.map(lambda x: x.replace('Ratio', '').strip())
    
    # Parse data
    sub_data = sub_data.applymap(parse_value)
    
    sub_data.loc[:, 'Year'] = year
    
    dataset.append(sub_data)
# Out:
# Processing: qs_data/2012.txt
# Processing: qs_data/2014.txt
# Processing: qs_data/2015.txt
# Processing: qs_data/2016.txt
# Processing: qs_data/2017.txt
# Processing: qs_data/2018.txt
# Processing: qs_data/2019.txt
# Processing: qs_data/2020.txt
# Processing: qs_data/2021.txt
# Processing: qs_data/2022.txt

# %%
dataset[0].head()
# Out:
#         City Natural Sciences Life Sciences And Medicine  \
# 0  CAMBRIDGE            95.06                      60.89
# 1  CAMBRIDGE             98.5                      82.75
# 2  CAMBRIDGE              100                        100
# 3     LONDON            40.24                      49.02
# 4     OXFORD            89.84                      78.11
#
#   Engineering And Technology Arts And Humanities International Students  \
# 0                        100               46.27                   96.5
# 1                      66.51               95.21                     96
# 2                      46.14                 100                   78.4
# 3                      33.13               54.56                   99.9
# 4                       52.7               97.66                   95.8
#
#   Social Sciences And Management Citations Per Faculty Faculty Student  \
# 0                          64.62                  99.3            99.9
# 1                          72.97                    97            98.3
# 2                            100                   100            98.6
# 3                          42.15                    94            98.4
# 4                          76.47                  89.4             100
#
#   International Faculty Academic Reputation Employer Reputation  \
# 0                  86.4                 100                 100
# 1                  98.2                 100                 100
# 2                    90                 100                 100
# 3                  96.3                99.6                95.6
# 4                    98                 100                 100
#
#          Location     NID Overall Score         Region  \
# 0   UNITED STATES  294850           100  NORTH AMERICA
# 1  UNITED KINGDOM  294561         99.78         EUROPE
# 2   UNITED STATES  294270         99.15  NORTH AMERICA
# 3  UNITED KINGDOM  294014         98.69         EUROPE
# 4  UNITED KINGDOM  294654         98.57         EUROPE
#
#                                     University  Year
# 0  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)  2012
# 1                      UNIVERSITY OF CAMBRIDGE  2012
# 2                           HARVARD UNIVERSITY  2012
# 3                                          UCL  2012
# 4                         UNIVERSITY OF OXFORD  2012

# %%
dataset[4].head()
# Out:
#         City International Students Citations Per Faculty Faculty Student  \
# 0  CAMBRIDGE                   96.6                  99.9             100
# 1   STANFORD                     74                  99.7             100
# 2  CAMBRIDGE                   70.4                   100            98.5
# 3  CAMBRIDGE                   97.8                  86.5             100
# 4   PASADENA                   87.7                   100             100
#
#   International Faculty Academic Reputation Employer Reputation  \
# 0                   100                 100                 100
# 1                  99.7                 100                 100
# 2                   100                 100                 100
# 3                  97.6                 100                 100
# 4                  91.2                99.4                80.7
#
#          Location     NID Overall Score         Region  \
# 0   UNITED STATES  294850           100  NORTH AMERICA
# 1   UNITED STATES  297282          98.7  NORTH AMERICA
# 2   UNITED STATES  294270          98.3  NORTH AMERICA
# 3  UNITED KINGDOM  294561          97.2         EUROPE
# 4   UNITED STATES  294562          96.9  NORTH AMERICA
#
#                                      University  Year
# 0   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)  2017
# 1                           STANFORD UNIVERSITY  2017
# 2                            HARVARD UNIVERSITY  2017
# 3                       UNIVERSITY OF CAMBRIDGE  2017
# 4  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)  2017

# %%
dataset[7].head()
# Out:
#         City International Students International Faculty Faculty Student  \
# 0  CAMBRIDGE                   94.1                   100             100
# 1   STANFORD                   67.7                  99.8             100
# 2  CAMBRIDGE                   62.2                  86.3            98.7
# 3     OXFORD                   98.5                  99.7             100
# 4   PASADENA                   87.3                  99.4             100
#
#   Citations Per Faculty Academic Reputation Employer Reputation  \
# 0                  99.8                 100                 100
# 1                  98.6                 100                 100
# 2                  99.6                 100                 100
# 3                  84.7                 100                 100
# 4                   100                97.8                81.2
#
#          Location     NID Overall Score         Region  \
# 0   UNITED STATES  294850           100  NORTH AMERICA
# 1   UNITED STATES  297282          98.4  NORTH AMERICA
# 2   UNITED STATES  294270          97.4  NORTH AMERICA
# 3  UNITED KINGDOM  294654          97.2         EUROPE
# 4   UNITED STATES  294562          96.9  NORTH AMERICA
#
#                                      University  Year
# 0   MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)  2020
# 1                           STANFORD UNIVERSITY  2020
# 2                            HARVARD UNIVERSITY  2020
# 3                          UNIVERSITY OF OXFORD  2020
# 4  CALIFORNIA INSTITUTE OF TECHNOLOGY (CALTECH)  2020

# %%
dataset_df = pd.concat(dataset, ignore_index=True, sort=False)

# %%
dataset_df.head(3)
# Out:
#         City Natural Sciences Life Sciences And Medicine  \
# 0  CAMBRIDGE            95.06                      60.89
# 1  CAMBRIDGE             98.5                      82.75
# 2  CAMBRIDGE              100                        100
#
#   Engineering And Technology Arts And Humanities International Students  \
# 0                        100               46.27                   96.5
# 1                      66.51               95.21                     96
# 2                      46.14                 100                   78.4
#
#   Social Sciences And Management Citations Per Faculty Faculty Student  \
# 0                          64.62                  99.3            99.9
# 1                          72.97                    97            98.3
# 2                            100                   100            98.6
#
#   International Faculty Academic Reputation Employer Reputation  \
# 0                  86.4                 100                 100
# 1                  98.2                 100                 100
# 2                    90                 100                 100
#
#          Location     NID Overall Score         Region  \
# 0   UNITED STATES  294850           100  NORTH AMERICA
# 1  UNITED KINGDOM  294561         99.78         EUROPE
# 2   UNITED STATES  294270         99.15  NORTH AMERICA
#
#                                     University  Year
# 0  MASSACHUSETTS INSTITUTE OF TECHNOLOGY (MIT)  2012
# 1                      UNIVERSITY OF CAMBRIDGE  2012
# 2                           HARVARD UNIVERSITY  2012

# %%
dataset_df.tail(3)
# Out:
#            City Natural Sciences Life Sciences And Medicine  \
# 10044     IRBID              NaN                        NaN
# 10045  ISTANBUL              NaN                        NaN
# 10046   ZAGAZIG              NaN                        NaN
#
#       Engineering And Technology Arts And Humanities International Students  \
# 10044                        NaN                 NaN                     11
# 10045                        NaN                 NaN                    8.9
# 10046                        NaN                 NaN                    1.9
#
#       Social Sciences And Management Citations Per Faculty Faculty Student  \
# 10044                            NaN                   2.2             1.9
# 10045                            NaN                   5.4             6.1
# 10046                            NaN                   2.2             3.4
#
#       International Faculty Academic Reputation Employer Reputation Location  \
# 10044                   1.2                 9.3                10.2   JORDAN
# 10045                   1.1                 5.6                10.5   TURKEY
# 10046                     1                 4.7                 2.8    EGYPT
#
#           NID Overall Score  Region                   University  Year
# 10044  297384                  ASIA           YARMOUK UNIVERSITY  2022
# 10045  309595                  ASIA  YILDIZ TECHNICAL UNIVERSITY  2022
# 10046  297612                AFRICA           ZAGAZIG UNIVERSITY  2022

# %%
dataset_df.loc[
    dataset_df.NID == '294014'
]
# Out:
#         City Natural Sciences Life Sciences And Medicine  \
# 3     LONDON            40.24                      49.02
# 869   LONDON              NaN                       85.4
# 1771  LONDON              NaN                       89.2
# 2657  LONDON              NaN                       87.6
# 3571  LONDON              NaN                        NaN
# 4504  LONDON              NaN                        NaN
# 5484  LONDON              NaN                        NaN
# 6500  LONDON              NaN                        NaN
# 7571  LONDON              NaN                        NaN
# 8755  LONDON              NaN                        NaN
#
#      Engineering And Technology Arts And Humanities International Students  \
# 3                         33.13               54.56                   99.9
# 869                        75.9                85.6                    100
# 1771                       81.7                84.4                    100
# 2657                       80.4                84.7                   99.9
# 3571                        NaN                 NaN                    100
# 4504                        NaN                 NaN                    100
# 5484                        NaN                 NaN                    100
# 6500                        NaN                 NaN                    100
# 7571                        NaN                 NaN                    100
# 8755                        NaN                 NaN                    100
#
#      Social Sciences And Management Citations Per Faculty Faculty Student  \
# 3                             42.15                    94            98.4
# 869                            81.2                  95.6            98.9
# 1771                           81.8                  97.4              99
# 2657                           81.9                    88            98.6
# 3571                            NaN                  79.1            98.7
# 4504                            NaN                  74.7            99.1
# 5484                            NaN                  66.2            99.2
# 6500                            NaN                  76.7            98.1
# 7571                            NaN                  65.4            98.4
# 8755                            NaN                    78              99
#
#      International Faculty Academic Reputation Employer Reputation  \
# 3                     96.3                99.6                95.6
# 869                   96.5                99.9                98.7
# 1771                  96.8                99.9                99.4
# 2657                  95.5                99.9                99.8
# 3571                  99.1                99.8                99.3
# 4504                  96.6                99.7                99.5
# 5484                  98.7                99.3                99.2
# 6500                  99.1                99.3                98.7
# 7571                  99.3                99.4                98.3
# 8755                  99.5                99.4                98.9
#
#             Location     NID Overall Score  Region University  Year
# 3     UNITED KINGDOM  294014         98.69  EUROPE        UCL  2012
# 869   UNITED KINGDOM  294014          98.9  EUROPE        UCL  2014
# 1771  UNITED KINGDOM  294014          99.2  EUROPE        UCL  2015
# 2657  UNITED KINGDOM  294014          97.2  EUROPE        UCL  2016
# 3571  UNITED KINGDOM  294014          95.6  EUROPE        UCL  2017
# 4504  UNITED KINGDOM  294014          94.6  EUROPE        UCL  2018
# 5484  UNITED KINGDOM  294014          92.9  EUROPE        UCL  2019
# 6500  UNITED KINGDOM  294014          94.8  EUROPE        UCL  2020
# 7571  UNITED KINGDOM  294014          92.9  EUROPE        UCL  2021
# 8755  UNITED KINGDOM  294014          95.4  EUROPE        UCL  2022

# %%
dataset_df.to_csv('../data_raw/QS_World_Rankings.csv')
